# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import os
import requests

# %%
if not os.path.exists('sales_textbook.txt'):
    url = 'https://github.com/861482002/little_gpt/blob/main/sales_textbook.txt'
    with open ('sales_textbook.txt','wb') as f:
        f.write(requests.get(url).connent)

# %%
with open('sales_textbook.txt','r') as f:
    text = f.read()

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
tokenized_text = encoding.encode(text)
len(tokenized_text)

# 放入tensor中
tokenized_text = torch.tensor(tokenized_text,dtype=torch.long)

# %%
# hyperparameters
context_length = 16
d_model = 64  # 512
batch_size = 4

# %%
train_idx= int(len(tokenized_text)*0.9)
train_text = tokenized_text[:train_idx]
valid_text = tokenized_text[train_idx:]

# %%
data = train_text
idxs = torch.randint(low = 0,high=len(data)-context_length,size=(batch_size,))
idxs
x_batch  = torch.stack([data[idx:idx+context_length] for idx in idxs])
x_batch.shape
y_batch  = torch.stack([data[idx+1:idx+context_length+1] for idx in idxs])

# %%
import pandas as pd
pd.DataFrame(x_batch[0].numpy())
encoding.decode(x_batch[0].numpy())
# Out:
# ' Are they detail-oriented or more focused on the big picture? Do they prefer data'

# %%
max_token = tokenized_text.max().item()
max_token
input_embedding_lookup_table = nn.Embedding(max_token+1, d_model)
input_embedding_lookup_table.weight.data
x_batch_embedding = input_embedding_lookup_table(x_batch)
y_batch_embedding = input_embedding_lookup_table(y_batch)
x_batch_embedding.shape
# Out:
# torch.Size([4, 16, 64])

# %%
# get positional encoding
import math
position_embedding_lookup_table = torch.zeros(context_length,d_model)
#self.position_embedding = torch.zeros(content_len, embed_dim).to('cuda')
position = torch.arange(0,context_length,dtype=torch.float).unsqueeze(1)

div_term = torch.exp(torch.arange(0, d_model, 2).float()*(-math.log(10000.0) / d_model))
position_embedding_lookup_table[:, 0::2] = torch.sin(position * div_term)
position_embedding_lookup_table[:, 1::2] = torch.cos(position * div_term)
position_embedding_lookup_table = position_embedding_lookup_table.unsqueeze(0).expand(batch_size,-1,-1)

# %%
x= x_batch_embedding+position_embedding_lookup_table
y= y_batch_embedding+position_embedding_lookup_table
pd.DataFrame(x[0].detach().numpy())
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.218612  1.788117  2.400264  1.031008  0.910982  0.138553 -1.131008
# 1   1.813200  0.903602  0.967127  0.192570 -0.095071  0.002915  0.903043
# 2   1.556751 -0.194534  1.672482  0.271215  1.411734  2.535051  0.814001
# 3  -0.316982 -1.733106 -0.470343 -2.034199  3.136102  0.971029  0.693757
# 4  -0.264092 -0.352069  0.340876 -0.310432 -0.945087 -0.722260  1.245419
# 5  -1.568200  0.677098  0.915919 -2.184231  1.704880 -0.555135  2.840661
# 6  -0.764493  0.350506 -0.325435 -1.223385 -0.799583 -0.765017  1.686550
# 7  -0.517493  1.135344 -1.900184 -1.522075 -1.288279 -1.981827 -0.391271
# 8   1.328304 -2.685407  0.249823  0.300688  2.844992 -0.300315 -0.546217
# 9   0.003480  0.237919 -0.975078  1.276814 -0.253748  1.925521 -1.804177
# 10 -1.561655 -1.568230  0.597337  0.893068  0.028620 -0.393686  1.343479
# 11 -2.121692  0.804672  1.184491 -0.180334  0.847519  0.714074 -0.039512
# 12 -0.909902  0.463661  0.632729 -0.149020 -1.313944  0.521156 -1.492756
# 13  1.391896  1.270747 -0.032650 -1.487209  0.227641 -0.325922 -0.224409
# 14  1.370209 -0.170047 -1.386782 -1.981957  1.235771  1.342142  1.811485
# 15  2.075426 -0.560932 -1.303425  0.911724  0.400821  0.703050 -0.095675
#
#           7         8         9   ...        54        55        56        57  \
# 0   0.942997 -0.948632  2.140785  ...  0.368283  1.013156  0.221575  2.589410
# 1   2.160269  0.065238  1.558538  ... -0.611068  1.816341  0.858252  1.181332
# 2  -1.041074  0.571586  2.029367  ...  0.830700  0.497611 -1.267074  0.527428
# 3   1.692208  0.110737 -0.043776  ...  0.643054  2.573688  0.166150  1.894268
# 4  -0.373089  1.846434 -0.699097  ...  0.466575  1.077872 -0.175976  3.091024
# 5  -2.844838  1.532895 -0.485175  ...  0.021618  0.882815  0.503755  0.277263
# 6  -1.646681  1.482083 -0.130184  ... -0.224098  2.235899 -1.027425  1.929863
# 7   0.493888  0.014401 -1.669593  ... -1.009931  0.564792  0.071012  2.779937
# 8  -1.601347  0.970470 -1.003916  ... -0.751531  2.201408 -0.310600  0.173405
# 9  -0.511023 -0.754090 -0.461653  ...  0.083612  1.557601  0.949037  1.409660
# 10 -0.785627 -0.448465 -1.719560  ... -0.467374  0.223156  0.338654  0.574587
# 11 -2.234576 -0.799782 -1.582397  ...  0.412897  0.395011  0.333034  1.480216
# 12  0.691195 -1.356591 -0.042936  ...  0.869091  1.305252 -0.400139  0.813889
# 13  1.943768 -1.070274  0.042302  ... -0.606008  1.816326  0.862047  1.181324
# 14  1.329890 -0.221109 -0.231809  ...  0.252611  0.066549 -2.049066 -1.024921
# 15  0.189200 -1.222127  0.971421  ...  1.663728  1.441044 -1.820525  0.906032
#
#           58        59        60        61        62        63
# 0  -0.294613 -0.860994 -1.285852 -0.418323  0.120814  1.523187
# 1   0.149519  1.173612  0.275315  0.377620  0.834244  0.692025
# 2   0.897259  0.025689  0.360044  1.160596 -1.355803 -0.036895
# 3  -0.457613  0.483233  1.696635  1.662695 -2.175786  1.518104
# 4  -1.281722  1.224645  0.810255  0.222070  0.141022  1.380639
# 5   0.953482  1.201444  1.688272  0.708827  0.660205  3.572180
# 6  -0.952799 -0.285398 -0.857348  1.023650 -1.590967  2.604764
# 7  -0.090164  0.957154 -0.504051  2.274044  0.364735  1.626547
# 8   0.329639  2.605072  0.681884  1.840405 -1.448294  2.037240
# 9   0.566308  1.167118 -1.548111  1.434172  0.034056  1.254944
# 10 -1.823626  1.759189  0.386555  0.375475  2.107918  1.564685
# 11 -0.648718  0.613876 -0.107865  1.958865 -0.229187 -0.295088
# 12 -0.625791  2.469504 -0.235976  3.048973  1.163477  1.990859
# 13  0.152364  1.173608  0.277449  0.377617  0.835844  0.692023
# 14 -0.695348  1.077185  1.232952 -0.040654  0.352469  0.431665
# 15 -1.127955  2.449438 -1.166967 -0.768142 -0.114259  1.413334
#
# [16 rows x 64 columns]

# %%
Wq = nn.Linear(d_model,d_model)# in 64,out 64 神经网络
Wk = nn.Linear(d_model,d_model)
Wv = nn.Linear(d_model,d_model)

Q=Wq(x) # 矩阵相乘？数据经过线性层，维度不变
K=Wq(x)
V=Wq(x)
Q.shape
# Out:
# torch.Size([4, 16, 64])

# %%
# apply multi head
num_heads=4
Q = Q.reshape(batch_size,context_length,num_heads,d_model//num_heads).permute(0,2,1,3)
Q.shape
K = K.reshape(batch_size,context_length,num_heads,d_model//num_heads).permute(0,2,1,3)
V = V.reshape(batch_size,context_length,num_heads,d_model//num_heads).permute(0,2,1,3)

# %%
output = Q @ K.transpose(-2,-1)/math.sqrt(d_model//num_heads) # Attention(Q,K,V)=softmax(QK^T)/sqrt(dkey)V

# %%
mask = torch.triu(torch.ones(context_length,context_length),diagonal=1).bool()
output = output.masked_fill(mask,float('-inf'))
pd.DataFrame(output[0,0].detach().numpy())
# Out:
#           0         1         2         3         4         5         6   \
# 0   2.322870      -inf      -inf      -inf      -inf      -inf      -inf
# 1   0.666803 -0.002176      -inf      -inf      -inf      -inf      -inf
# 2  -0.025723  0.308878  0.791848      -inf      -inf      -inf      -inf
# 3   0.004385 -0.668528 -0.637418 -0.697493      -inf      -inf      -inf
# 4   0.969825  0.987722  0.576686  1.100946  0.460348      -inf      -inf
# 5   0.410144 -0.348216  1.331635  1.066867  2.020805  1.611115      -inf
# 6  -0.050603  0.400093  0.806138  0.596349 -0.053969 -0.251044  0.673670
# 7   0.074771 -0.026528 -0.392828 -0.363321 -0.779130 -1.332518 -0.431808
# 8   0.123239  0.347075  0.364217  0.451347  0.559084  0.474078  0.410623
# 9   0.969226  0.846728  0.762461  1.475680  1.557858  1.595029  1.451485
# 10  0.086249  0.431740  0.204557  0.165477 -0.157317 -0.140901  0.701099
# 11  0.329427  0.385116 -0.079206  0.296246 -0.275169  0.437430  0.137479
# 12  1.812491  1.330612  0.775072  1.890865  0.712071  0.567867  0.895084
# 13  0.804887  0.204408  0.273596  0.834951  1.418240  1.396690  0.868202
# 14  0.921064 -0.367253  0.346107  0.434013 -0.382117  0.273513  0.051564
# 15  0.361670  0.978567 -0.405151 -0.167163 -0.577368 -0.534598  0.432496
#
#           7         8         9         10        11        12        13  \
# 0       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 1       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 2       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 3       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 4       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 5       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 6       -inf      -inf      -inf      -inf      -inf      -inf      -inf
# 7  -0.713430      -inf      -inf      -inf      -inf      -inf      -inf
# 8   0.093795  0.260154      -inf      -inf      -inf      -inf      -inf
# 9  -0.156436 -0.318698 -0.271784      -inf      -inf      -inf      -inf
# 10 -0.193209  0.534667 -0.214326  0.229138      -inf      -inf      -inf
# 11  0.515840  0.396480 -0.097656  0.229108 -0.122087      -inf      -inf
# 12 -0.118140  0.392347  0.939443  0.277168  0.167195 -0.430926      -inf
# 13  0.381394  0.109553  0.130126  0.192936  0.252278 -0.376857 -0.153808
# 14  1.092149  0.599740  0.977071  0.602325  0.636527  0.211234  0.069761
# 15 -0.317900 -0.301576 -0.769601 -0.067547 -0.948973  0.778904  1.433597
#
#           14        15
# 0       -inf      -inf
# 1       -inf      -inf
# 2       -inf      -inf
# 3       -inf      -inf
# 4       -inf      -inf
# 5       -inf      -inf
# 6       -inf      -inf
# 7       -inf      -inf
# 8       -inf      -inf
# 9       -inf      -inf
# 10      -inf      -inf
# 11      -inf      -inf
# 12      -inf      -inf
# 13      -inf      -inf
# 14 -0.577935      -inf
# 15  1.450984  0.978595

# %%
# apply softmax
attention_score = F.softmax(output,dim=-1)# 永远对最后一个维度进行
attention_score
# Out:
# tensor([[[[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6613, 0.3387, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2145, 0.2997, 0.4858,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0881, 0.0483, 0.0518,  ..., 0.0338, 0.0000, 0.0000],
#           [0.1080, 0.0298, 0.0608,  ..., 0.0461, 0.0241, 0.0000],
#           [0.0578, 0.1071, 0.0268,  ..., 0.1688, 0.1717, 0.1071]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.8214, 0.1786, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6125, 0.1820, 0.2055,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0522, 0.0233, 0.0564,  ..., 0.0272, 0.0000, 0.0000],
#           [0.0448, 0.0433, 0.0540,  ..., 0.1224, 0.0173, 0.0000],
#           [0.0543, 0.0691, 0.0410,  ..., 0.0451, 0.0771, 0.0756]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3931, 0.6069, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2962, 0.1643, 0.5395,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0302, 0.0395, 0.0719,  ..., 0.0439, 0.0000, 0.0000],
#           [0.0276, 0.0357, 0.0961,  ..., 0.0547, 0.0435, 0.0000],
#           [0.0353, 0.0781, 0.0480,  ..., 0.0868, 0.0882, 0.0137]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4825, 0.5175, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3388, 0.3209, 0.3403,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0791, 0.0550, 0.0641,  ..., 0.0555, 0.0000, 0.0000],
#           [0.0608, 0.0547, 0.0591,  ..., 0.0404, 0.0848, 0.0000],
#           [0.0539, 0.0519, 0.0528,  ..., 0.0665, 0.0456, 0.1544]]],
#
#
#         [[[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4055, 0.5945, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3064, 0.2856, 0.4080,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0811, 0.1060, 0.0666,  ..., 0.0454, 0.0000, 0.0000],
#           [0.1573, 0.0488, 0.0215,  ..., 0.0609, 0.0289, 0.0000],
#           [0.0945, 0.0284, 0.0381,  ..., 0.1180, 0.1254, 0.1141]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6445, 0.3555, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3600, 0.2808, 0.3592,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.1395, 0.0159, 0.0907,  ..., 0.0436, 0.0000, 0.0000],
#           [0.0617, 0.0347, 0.0478,  ..., 0.0278, 0.0192, 0.0000],
#           [0.0372, 0.0291, 0.0524,  ..., 0.1873, 0.0471, 0.0481]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3711, 0.6289, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2520, 0.1084, 0.6397,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0656, 0.0804, 0.0613,  ..., 0.0788, 0.0000, 0.0000],
#           [0.0559, 0.0539, 0.0749,  ..., 0.0623, 0.0704, 0.0000],
#           [0.0538, 0.0727, 0.0589,  ..., 0.0979, 0.0293, 0.0904]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4198, 0.5802, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5452, 0.2271, 0.2276,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0459, 0.0796, 0.0810,  ..., 0.0338, 0.0000, 0.0000],
#           [0.0448, 0.0497, 0.0381,  ..., 0.0183, 0.0184, 0.0000],
#           [0.0264, 0.0499, 0.0379,  ..., 0.0680, 0.0536, 0.2730]]],
#
#
#         [[[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.7055, 0.2945, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4464, 0.3224, 0.2312,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.1756, 0.1191, 0.0457,  ..., 0.0267, 0.0000, 0.0000],
#           [0.0472, 0.0427, 0.0329,  ..., 0.0977, 0.0330, 0.0000],
#           [0.0309, 0.0327, 0.0443,  ..., 0.0757, 0.1486, 0.1832]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5896, 0.4104, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2289, 0.1755, 0.5955,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.1071, 0.0568, 0.1621,  ..., 0.1001, 0.0000, 0.0000],
#           [0.0323, 0.0426, 0.0599,  ..., 0.0843, 0.0319, 0.0000],
#           [0.0358, 0.0563, 0.0587,  ..., 0.1325, 0.0557, 0.0569]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3272, 0.6728, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3849, 0.1760, 0.4391,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0269, 0.0984, 0.1568,  ..., 0.0309, 0.0000, 0.0000],
#           [0.1167, 0.0302, 0.1017,  ..., 0.0638, 0.0201, 0.0000],
#           [0.0479, 0.0584, 0.0188,  ..., 0.0904, 0.1122, 0.1012]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5481, 0.4519, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4150, 0.2174, 0.3676,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0409, 0.0589, 0.0366,  ..., 0.0326, 0.0000, 0.0000],
#           [0.0410, 0.0347, 0.0533,  ..., 0.0350, 0.0511, 0.0000],
#           [0.0746, 0.0752, 0.0544,  ..., 0.0529, 0.0916, 0.2923]]],
#
#
#         [[[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.6925, 0.3075, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2992, 0.3123, 0.3885,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0311, 0.0513, 0.0913,  ..., 0.0403, 0.0000, 0.0000],
#           [0.0375, 0.0708, 0.0756,  ..., 0.0597, 0.0935, 0.0000],
#           [0.0248, 0.0296, 0.0341,  ..., 0.0494, 0.0682, 0.2161]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.4129, 0.5871, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3259, 0.3644, 0.3097,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0545, 0.1495, 0.0679,  ..., 0.0529, 0.0000, 0.0000],
#           [0.1064, 0.0547, 0.0254,  ..., 0.0206, 0.0778, 0.0000],
#           [0.0859, 0.0784, 0.0820,  ..., 0.1742, 0.0495, 0.0733]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3415, 0.6585, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2793, 0.3649, 0.3558,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0393, 0.0339, 0.0799,  ..., 0.0467, 0.0000, 0.0000],
#           [0.0843, 0.0358, 0.0568,  ..., 0.0587, 0.0851, 0.0000],
#           [0.0251, 0.0819, 0.0463,  ..., 0.0998, 0.1148, 0.0417]],
#
#          [[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.5951, 0.4049, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3520, 0.3854, 0.2625,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0604, 0.0724, 0.0666,  ..., 0.0607, 0.0000, 0.0000],
#           [0.0430, 0.0302, 0.0634,  ..., 0.0308, 0.0209, 0.0000],
#           [0.0281, 0.0414, 0.0292,  ..., 0.1019, 0.0632, 0.1670]]]],
#        grad_fn=<SoftmaxBackward0>)

# %%
# apply attention @v
A = attention_score @ V
A.shape # 批次，4个头，句子长度，每个头的维度
# Out:
# torch.Size([4, 4, 16, 16])

# %%
# apply concatenate 切好的头合并回来
A= A.transpose(1,2).reshape(batch_size,context_length,d_model)
A.shape
Wo= nn.Linear(d_model,d_model)
output = Wo(A)
output.shape
# Out:
# torch.Size([4, 16, 64])

# %%
# apply residual connection 残差连接
output = output+x

# %%
# apply layer normalization
layer_norm = nn.LayerNorm(d_model) # 使数据分布更加均匀
output = layer_norm(output)

# %%
# apply feed forward network
output = nn.Linear(d_model,d_model*4)(output)
output = nn.ReLU(output)
output = nn.Linear(d_model*4,d_model)(output)
